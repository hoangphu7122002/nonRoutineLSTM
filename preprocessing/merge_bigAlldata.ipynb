# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
work_not_done = pd.read_csv('/content/drive/MyDrive/Timeseries_test/HP_preprocessing/not_done_alldata.csv',index_col = '0')
work_done = pd.read_csv('/content/drive/MyDrive/Timeseries_test/HP_preprocessing/done_alldata.csv',index_col = '0')
day_not_done = pd.read_csv('/content/drive/MyDrive/Timeseries_test/HP_preprocessing/not_done_alldata_day.csv',index_col = '0')
day_done = pd.read_csv('/content/drive/MyDrive/Timeseries_test/HP_preprocessing/done_alldata_day.csv',index_col = '0')

# %%
all_data = pd.read_csv('/content/drive/MyDrive/Timeseries_test/HP_preprocessing/alldata.csv',index_col = '0')

# %%
all_data = all_data.merge(work_not_done,on=['0'])

# %%
all_data = all_data.merge(work_done,on=['0'])
all_data = all_data.merge(day_not_done,on=['0'])
all_data = all_data.merge(day_done,on=['0'])

# %%
all_data.to_csv('/content/drive/MyDrive/Timeseries_test/big_alldata.csv')
